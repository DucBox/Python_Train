# %% [markdown]
# <a href="https://colab.research.google.com/github/DucBox/Python_Train/blob/main/Day_27_(Work_with_Text_Data_underthesea_lib).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !pip install underthesea
# Lib for Vietnamese

# %%
import underthesea

# %%
from underthesea import pos_tag
from underthesea import word_tokenize
from underthesea import classify
from underthesea import sentiment

# %%
modules = [module for module in dir(underthesea) if not module.startswith('__')]
print(modules)
# Out:
# ['chunk', 'classify', 'corpus', 'dependency_parse', 'feature_engineering', 'file_utils', 'infile', 'model_fetcher', 'models', 'ner', 'os', 'pipeline', 'pos_tag', 'sent_tokenize', 'sentiment', 'sys', 'text_normalize', 'util', 'utils', 'version_file', 'version_info', 'word_tokenize']

# %%
pos_tag('Tôi đang học')
# Out:
# [('Tôi', 'P'), ('đang', 'R'), ('học', 'V')]

# %%
input = 'Giá cổ phiếu đang tăng'
classify(input), word_tokenize(input)
# Out:
# (['kinh_doanh'], ['Giá', 'cổ phiếu', 'đang', 'tăng'])

# %%
sentiment_sentence = 'Tôi rất vui'
sentiment(sentiment_sentence)
# Out:
# 2024-05-07 09:17:30,867 https://github.com/undertheseanlp/playground/releases/download/1.3.x/sa_svm_vlsp2016-sa_20210107.zip not found in cache, downloading to /tmp/tmpxisu7nrp
# 100%|██████████| 2234880/2234880 [00:00<00:00, 6557062.08B/s]
# 2024-05-07 09:17:33,900 copying /tmp/tmpxisu7nrp to cache at /root/.underthesea/models/sa_svm_vlsp2016-sa_20210107.zip
# 2024-05-07 09:17:33,907 removing temp file /tmp/tmpxisu7nrp
# 'positive'
