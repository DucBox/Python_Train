# %% [markdown]
# <a href="https://colab.research.google.com/github/DucBox/Python_Train/blob/main/Day_13_(Linear_Research).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst_data = [1,7,None,8,9,None,10]

# %%
lst_none = []

# %%
for index, value in enumerate(lst_data):
  if value == None:
    lst_none.append(index)

# %%
print(lst_none)
# Out:
# [2, 5]

# %% [markdown]
# ![image.png](data:image/png;base64,...)
