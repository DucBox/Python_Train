# %% [markdown]
# <a href="https://colab.research.google.com/github/DucBox/Python_Train/blob/main/Day_26_(Work_with_Image_Data).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('/content/img-6.jpg')

# %%
plt.imshow(img)
plt.show()

# %%
new_img =img.astype(np.float32) - 50
new_img = np.clip(new_img, 0, 255)
new_img = new_img.astype(np.uint8)
new_img
# Out:
# array([[155, 155, 155, ..., 155, 155, 155],
#        [155, 155, 155, ..., 155, 155, 155],
#        [155, 155, 155, ..., 155, 155, 155],
#        ...,
#        [155, 155, 155, ..., 155, 155, 155],
#        [155, 155, 155, ..., 155, 155, 155],
#        [155, 155, 155, ..., 155, 155, 155]], dtype=uint8)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
img
# Out:
# array([[[ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         ...,
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250]],
#
#        [[ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         ...,
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250]],
#
#        [[ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         ...,
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250]],
#
#        ...,
#
#        [[ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         ...,
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250]],
#
#        [[ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         ...,
#         [ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250]],
#
#        [[ 93, 254, 250],
#         [ 93, 254, 250],
#         [ 93, 254, 250],
# ...
