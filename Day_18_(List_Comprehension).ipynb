# %% [markdown]
# <a href="https://colab.research.google.com/github/DucBox/Python_Train/blob/main/Day_18_(List_Comprehension).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print([i for i in range(10) if i % 2 == 0])
# Out:
# [0, 2, 4, 6, 8]

# %%
input = 'I love AI and listen to music'
stop_word = ['I','love','and','to']

# %%
result = [word for word in input.split() if word not in stop_word]
result
# Out:
# ['AI', 'listen', 'music']
